# %%
# !pip install google-api-python-client
# Out:
# Requirement already satisfied: google-api-python-client in /Users/upendra/anaconda3/lib/python3.11/site-packages (2.127.0)
# Requirement already satisfied: httplib2<1.dev0,>=0.19.0 in /Users/upendra/anaconda3/lib/python3.11/site-packages (from google-api-python-client) (0.22.0)
# Requirement already satisfied: google-auth!=2.24.0,!=2.25.0,<3.0.0.dev0,>=1.32.0 in /Users/upendra/anaconda3/lib/python3.11/site-packages (from google-api-python-client) (2.23.2)
# Requirement already satisfied: google-auth-httplib2<1.0.0,>=0.2.0 in /Users/upendra/anaconda3/lib/python3.11/site-packages (from google-api-python-client) (0.2.0)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5 in /Users/upendra/anaconda3/lib/python3.11/site-packages (from google-api-python-client) (2.18.0)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in /Users/upendra/anaconda3/lib/python3.11/site-packages (from google-api-python-client) (4.1.1)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in /Users/upendra/anaconda3/lib/python3.11/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (1.63.0)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0.dev0,>=3.19.5 in /Users/upendra/anaconda3/lib/python3.11/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (4.24.4)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in /Users/upendra/anaconda3/lib/python3.11/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (1.23.0)
# Requirement already satisfied: requests<3.0.0.dev0,>=2.18.0 in /Users/upendra/anaconda3/lib/python3.11/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (2.31.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /Users/upendra/anaconda3/lib/python3.11/site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0.dev0,>=1.32.0->google-api-python-client) (5.3.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/upendra/anaconda3/lib/python3.11/site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0.dev0,>=1.32.0->google-api-python-client) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Users/upendra/anaconda3/lib/python3.11/site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0.dev0,>=1.32.0->google-api-python-client) (4.9)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in /Users/upendra/anaconda3/lib/python3.11/site-packages (from httplib2<1.dev0,>=0.19.0->google-api-python-client) (3.0.9)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /Users/upendra/anaconda3/lib/python3.11/site-packages (from pyasn1-modules>=0.2.1->google-auth!=2.24.0,!=2.25.0,<3.0.0.dev0,>=1.32.0->google-api-python-client) (0.4.8)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/upendra/anaconda3/lib/python3.11/site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/upendra/anaconda3/lib/python3.11/site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/upendra/anaconda3/lib/python3.11/site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/upendra/anaconda3/lib/python3.11/site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (2023.7.22)

# %%
# %pip install streamlit
# Out:
# Requirement already satisfied: streamlit in /Users/upendra/anaconda3/lib/python3.11/site-packages (1.33.0)
# Requirement already satisfied: altair<6,>=4.0 in /Users/upendra/anaconda3/lib/python3.11/site-packages (from streamlit) (5.3.0)
# Requirement already satisfied: blinker<2,>=1.0.0 in /Users/upendra/anaconda3/lib/python3.11/site-packages (from streamlit) (1.7.0)
# Requirement already satisfied: cachetools<6,>=4.0 in /Users/upendra/anaconda3/lib/python3.11/site-packages (from streamlit) (5.3.1)
# Requirement already satisfied: click<9,>=7.0 in /Users/upendra/anaconda3/lib/python3.11/site-packages (from streamlit) (8.0.4)
# Requirement already satisfied: numpy<2,>=1.19.3 in /Users/upendra/anaconda3/lib/python3.11/site-packages (from streamlit) (1.24.3)
# Requirement already satisfied: packaging<25,>=16.8 in /Users/upendra/anaconda3/lib/python3.11/site-packages (from streamlit) (23.1)
# Requirement already satisfied: pandas<3,>=1.3.0 in /Users/upendra/anaconda3/lib/python3.11/site-packages (from streamlit) (2.0.3)
# Requirement already satisfied: pillow<11,>=7.1.0 in /Users/upendra/anaconda3/lib/python3.11/site-packages (from streamlit) (9.4.0)
# Requirement already satisfied: protobuf<5,>=3.20 in /Users/upendra/anaconda3/lib/python3.11/site-packages (from streamlit) (4.24.4)
# Requirement already satisfied: pyarrow>=7.0 in /Users/upendra/anaconda3/lib/python3.11/site-packages (from streamlit) (11.0.0)
# Requirement already satisfied: requests<3,>=2.27 in /Users/upendra/anaconda3/lib/python3.11/site-packages (from streamlit) (2.31.0)
# Requirement already satisfied: rich<14,>=10.14.0 in /Users/upendra/anaconda3/lib/python3.11/site-packages (from streamlit) (13.7.1)
# Requirement already satisfied: tenacity<9,>=8.1.0 in /Users/upendra/anaconda3/lib/python3.11/site-packages (from streamlit) (8.2.2)
# Requirement already satisfied: toml<2,>=0.10.1 in /Users/upendra/anaconda3/lib/python3.11/site-packages (from streamlit) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.3.0 in /Users/upendra/anaconda3/lib/python3.11/site-packages (from streamlit) (4.7.1)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in /Users/upendra/anaconda3/lib/python3.11/site-packages (from streamlit) (3.1.43)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in /Users/upendra/anaconda3/lib/python3.11/site-packages (from streamlit) (0.9.0b0)
# Requirement already satisfied: tornado<7,>=6.0.3 in /Users/upendra/anaconda3/lib/python3.11/site-packages (from streamlit) (6.3.2)
# Requirement already satisfied: jinja2 in /Users/upendra/anaconda3/lib/python3.11/site-packages (from altair<6,>=4.0->streamlit) (3.1.2)
# Requirement already satisfied: jsonschema>=3.0 in /Users/upendra/anaconda3/lib/python3.11/site-packages (from altair<6,>=4.0->streamlit) (4.17.3)
# Requirement already satisfied: toolz in /Users/upendra/anaconda3/lib/python3.11/site-packages (from altair<6,>=4.0->streamlit) (0.12.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /Users/upendra/anaconda3/lib/python3.11/site-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.11)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/upendra/anaconda3/lib/python3.11/site-packages (from pandas<3,>=1.3.0->streamlit) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/upendra/anaconda3/lib/python3.11/site-packages (from pandas<3,>=1.3.0->streamlit) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /Users/upendra/anaconda3/lib/python3.11/site-packages (from pandas<3,>=1.3.0->streamlit) (2023.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/upendra/anaconda3/lib/python3.11/site-packages (from requests<3,>=2.27->streamlit) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/upendra/anaconda3/lib/python3.11/site-packages (from requests<3,>=2.27->streamlit) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/upendra/anaconda3/lib/python3.11/site-packages (from requests<3,>=2.27->streamlit) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/upendra/anaconda3/lib/python3.11/site-packages (from requests<3,>=2.27->streamlit) (2023.7.22)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/upendra/anaconda3/lib/python3.11/site-packages (from rich<14,>=10.14.0->streamlit) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/upendra/anaconda3/lib/python3.11/site-packages (from rich<14,>=10.14.0->streamlit) (2.15.1)
# Requirement already satisfied: smmap<6,>=3.0.1 in /Users/upendra/anaconda3/lib/python3.11/site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit) (5.0.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/upendra/anaconda3/lib/python3.11/site-packages (from jinja2->altair<6,>=4.0->streamlit) (2.1.1)
# Requirement already satisfied: attrs>=17.4.0 in /Users/upendra/anaconda3/lib/python3.11/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (22.1.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /Users/upendra/anaconda3/lib/python3.11/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.18.0)
# Requirement already satisfied: mdurl~=0.1 in /Users/upendra/anaconda3/lib/python3.11/site-packages (from markdown-it-py>=2.2.0->rich<14,>=10.14.0->streamlit) (0.1.0)
# Requirement already satisfied: six>=1.5 in /Users/upendra/anaconda3/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas<3,>=1.3.0->streamlit) (1.16.0)

# %%
import googleapiclient.discovery

# %%
api_service_name = "youtube"
api_version = "v3"

# %%
api_Key = "AIzaSyAXpXnTSI52phjTaXrKqM1MgTERyJECjxg"
youtube = googleapiclient.discovery.build(api_service_name, api_version, developerKey=api_Key)

# %%
request = youtube.channels().list(
part = "snippet,contentDetails,statistics",
id = "UCtGbExCzlwmsyWKpxLnyEww"
)
response = request.execute()

# %%
response['items']
# Out:
# [{'kind': 'youtube#channel',
#   'etag': 'QwXJlc-QgIIdfy99PAW98X52teE',
#   'id': 'UCtGbExCzlwmsyWKpxLnyEww',
#   'snippet': {'title': 'SHUBH',
#    'description': 'INDEPENDENT ARTIST\nSinger, songwriter and musician Shubh was born for the spotlight and his career is shaping up to be nothing short of iconic. The Punjabi-Canadian rapper and vocalist took over Hip-Hop music and culture on his own terms revising trap, hiphop and R&B through an ambitious vision. Thanks to his introspective rap style and his golden touch songwriting, he has sustained an enormous presence. Known for his breakout debut single We Rollin, Toronto based Shubh made a rapid rise in mainstream music industry. With over 250+ million career streams in less than 6 months since his debut, he continues to reign as one of the biggest emerging artist the world has ever seen. With such a rapid rise and a relentless stream of critical and commercial hits, its clear that Shubh is one of the greatest modern success stories in Hip-hop.\n\nFor Business & Inquiries:- +91 9820174336\nEmail: info@shubhworldwide.com\n\n',
#    'customUrl': '@shubhworldwide',
#    'publishedAt': '2021-09-16T15:07:50.89269Z',
#    'thumbnails': {'default': {'url': 'https://yt3.ggpht.com/O4p5Qy9p7Clwl_JbAOhEs5X-uNYdUVdsOF6TkVFQ6cohk1_REoJs8_3F1AxbhvRev8jtnI9ZCg=s88-c-k-c0x00ffffff-no-nd-rj',
#      'width': 88,
#      'height': 88},
#     'medium': {'url': 'https://yt3.ggpht.com/O4p5Qy9p7Clwl_JbAOhEs5X-uNYdUVdsOF6TkVFQ6cohk1_REoJs8_3F1AxbhvRev8jtnI9ZCg=s240-c-k-c0x00ffffff-no-nd-rj',
#      'width': 240,
#      'height': 240},
#     'high': {'url': 'https://yt3.ggpht.com/O4p5Qy9p7Clwl_JbAOhEs5X-uNYdUVdsOF6TkVFQ6cohk1_REoJs8_3F1AxbhvRev8jtnI9ZCg=s800-c-k-c0x00ffffff-no-nd-rj',
#      'width': 800,
#      'height': 800}},
#    'localized': {'title': 'SHUBH',
#     'description': 'INDEPENDENT ARTIST\nSinger, songwriter and musician Shubh was born for the spotlight and his career is shaping up to be nothing short of iconic. The Punjabi-Canadian rapper and vocalist took over Hip-Hop music and culture on his own terms revising trap, hiphop and R&B through an ambitious vision. Thanks to his introspective rap style and his golden touch songwriting, he has sustained an enormous presence. Known for his breakout debut single We Rollin, Toronto based Shubh made a rapid rise in mainstream music industry. With over 250+ million career streams in less than 6 months since his debut, he continues to reign as one of the biggest emerging artist the world has ever seen. With such a rapid rise and a relentless stream of critical and commercial hits, its clear that Shubh is one of the greatest modern success stories in Hip-hop.\n\nFor Business & Inquiries:- +91 9820174336\nEmail: info@shubhworldwide.com\n\n'}},
#   'contentDetails': {'relatedPlaylists': {'likes': '',
#     'uploads': 'UUtGbExCzlwmsyWKpxLnyEww'}},
#   'statistics': {'viewCount': '1838570667',
#    'subscriberCount': '4870000',
#    'hiddenSubscriberCount': False,
#    'videoCount': '28'}}]

# %%
def channel_data(c_id):
    request = youtube.channels().list(
    part = "snippet,contentDetails,statistics",
    id = c_id
    )
    response = request.execute()
    
    data = {
        "channel_id":response['items'][0]['id'],
        "channel_name":response['items'][0]['snippet']['title'],
        "channel_des":response['items'][0]['snippet']['description'],
        "channel_pub":response['items'][0]['snippet']['publishedAt'],
        "channel_pid":response['items'][0]['contentDetails']['relatedPlaylists']['uploads'],
        "channel_sub":response['items'][0]['statistics']['subscriberCount'],
        "channel_vc":response['items'][0]['statistics']['viewCount'],
        "total_videos":response['items'][0]['statistics']['videoCount']
    }
    return data

# %%
channel_details = channel_data("UCtGbExCzlwmsyWKpxLnyEww")

# %%
channel_details
# Out:
# {'channel_id': 'UCtGbExCzlwmsyWKpxLnyEww',
#  'channel_name': 'SHUBH',
#  'channel_des': 'INDEPENDENT ARTIST\nSinger, songwriter and musician Shubh was born for the spotlight and his career is shaping up to be nothing short of iconic. The Punjabi-Canadian rapper and vocalist took over Hip-Hop music and culture on his own terms revising trap, hiphop and R&B through an ambitious vision. Thanks to his introspective rap style and his golden touch songwriting, he has sustained an enormous presence. Known for his breakout debut single We Rollin, Toronto based Shubh made a rapid rise in mainstream music industry. With over 250+ million career streams in less than 6 months since his debut, he continues to reign as one of the biggest emerging artist the world has ever seen. With such a rapid rise and a relentless stream of critical and commercial hits, its clear that Shubh is one of the greatest modern success stories in Hip-hop.\n\nFor Business & Inquiries:- +91 9820174336\nEmail: info@shubhworldwide.com\n\n',
#  'channel_pub': '2021-09-16T15:07:50.89269Z',
#  'channel_pid': 'UUtGbExCzlwmsyWKpxLnyEww',
#  'channel_sub': '4870000',
#  'channel_vc': '1838570667',
#  'total_videos': '28'}

# %%
#UCtGbExCzlwmsyWKpxLnyEww

# %%
# FUNCTION TO GET CHANNEL DETAILS
def get_channel_details(channel_id):
    ch_data = []
    response = youtube.channels().list(part = 'snippet,contentDetails,statistics',
                                     id= channel_id).execute()

    for i in range(len(response['items'])):
        data = dict(Channel_id = channel_id[i],
                    Channel_name = response['items'][i]['snippet']['title'],
                    Playlist_id = response['items'][i]['contentDetails']['relatedPlaylists']['uploads'],
                    Subscribers = response['items'][i]['statistics']['subscriberCount'],
                    Views = response['items'][i]['statistics']['viewCount'],
                    Total_videos = response['items'][i]['statistics']['videoCount'],
                    Description = response['items'][i]['snippet']['description'],
                    published_At = response['items'][i]['snippet']['publishedAt']
                    )
        ch_data.append(data)
    return ch_data

# %%
ch_details = get_channel_details("UCtGbExCzlwmsyWKpxLnyEww")

ch_details
# Out:
# [{'Channel_id': 'U',
#   'Channel_name': 'SHUBH',
#   'Playlist_id': 'UUtGbExCzlwmsyWKpxLnyEww',
#   'Subscribers': '4870000',
#   'Views': '1838570667',
#   'Total_videos': '28',
#   'Description': 'INDEPENDENT ARTIST\nSinger, songwriter and musician Shubh was born for the spotlight and his career is shaping up to be nothing short of iconic. The Punjabi-Canadian rapper and vocalist took over Hip-Hop music and culture on his own terms revising trap, hiphop and R&B through an ambitious vision. Thanks to his introspective rap style and his golden touch songwriting, he has sustained an enormous presence. Known for his breakout debut single We Rollin, Toronto based Shubh made a rapid rise in mainstream music industry. With over 250+ million career streams in less than 6 months since his debut, he continues to reign as one of the biggest emerging artist the world has ever seen. With such a rapid rise and a relentless stream of critical and commercial hits, its clear that Shubh is one of the greatest modern success stories in Hip-hop.\n\nFor Business & Inquiries:- +91 9820174336\nEmail: info@shubhworldwide.com\n\n',
#   'published_At': '2021-09-16T15:07:50.89269Z'}]

# %%
# FUNCTION TO GET VIDEO IDS
def get_channel_videos(channel_id):
    video_ids = []
    # get Uploads playlist id
    res = youtube.channels().list(id=channel_id, 
                                  part='contentDetails').execute()
    playlist_id = res['items'][0]['contentDetails']['relatedPlaylists']['uploads']
    next_page_token = None
    
    while True:
        res = youtube.playlistItems().list(playlistId=playlist_id, 
                                           part='snippet', 
                                           maxResults=50,
                                           pageToken=next_page_token).execute()
        
        for i in range(len(res['items'])):
            video_ids.append(res['items'][i]['snippet']['resourceId']['videoId'])
        next_page_token = res.get('nextPageToken')
        
        if next_page_token is None:
            break
    return video_ids

# %%
ch_videos = get_channel_videos("UCtGbExCzlwmsyWKpxLnyEww")
ch_videos
# Out:
# ['j2zxCw3voU8',
#  'jjiC7PfoIaY',
#  'Y5HIqjf3rek',
#  'd2ofxg8pHfQ',
#  'IAvw60x0Kn4',
#  'EWlQVvCX8y0',
#  'LjfY3qSTBQc',
#  '0pWsCiBvLOk',
#  'bJfI6x1obEg',
#  '4tywp83zkmk',
#  'vyrPwLoIYkc',
#  'oUOdKwzuvX0',
#  '0mCVpUDCkEk',
#  'xOeniWOjA3M',
#  'DAqxAqq_jhg',
#  'FxoBzZhEdjo',
#  'KaZRiIsQjhM',
#  'SeC91H4nWCk',
#  'FJm2CR1o_hI',
#  'IrzowkE4h1w',
#  'eD3TP-C3nYE',
#  'xR3V5Ow2dTI',
#  'I1nX5EuvwzE',
#  '6RrEQJNZwPQ',
#  'hV8EGTjzD2s',
#  'ixgaS-3FfK4',
#  '9CvwbW9UhJc',
#  'RLhuPD2ASKE']

# %%
# FUNCTION TO GET VIDEO DETAILS
def get_video_details(v_ids):
    video_stats = []
    
    for i in range(0, len(v_ids), 50):
        response = youtube.videos().list(
                    part="snippet,contentDetails,statistics",
                    id=','.join(v_ids[i:i+50])).execute()
        for video in response['items']:
            video_details = dict(Channel_name = video['snippet']['channelTitle'],
                                Channel_id = video['snippet']['channelId'],
                                Video_id = video['id'],
                                Title = video['snippet']['title'],
                                Tags = video['snippet'].get('tags'),
                                Thumbnail = video['snippet']['thumbnails']['default']['url'],
                                Description = video['snippet']['description'],
                                Published_date = video['snippet']['publishedAt'],
                                Duration = video['contentDetails']['duration'],
                                Views = video['statistics']['viewCount'],
                                Likes = video['statistics'].get('likeCount'),
                                Comments = video['statistics'].get('commentCount'),
                                Favorite_count = video['statistics']['favoriteCount'],
                                Definition = video['contentDetails']['definition'],
                                Caption_status = video['contentDetails']['caption']
                               )
            video_stats.append(video_details)
    return video_stats

# %%
videos_details = get_video_details(ch_videos)
videos_details
# Out:
# [{'Channel_name': 'SHUBH',
#   'Channel_id': 'UCtGbExCzlwmsyWKpxLnyEww',
#   'Video_id': 'j2zxCw3voU8',
#   'Title': 'Shubh - Bandana (Official Music Video)',
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/j2zxCw3voU8/default.jpg',
#   'Description': 'Singer/Lyrics/Composer – Shubh\nMusic Production – Sickboi\nMix - mixedbyswitch , Gurjit Thind\nMaster – mixedbyswitch\nVideo Director - Rubbal GTR\n\nINSTAGRAM - https://www.instagram.com/shubhworldwide/',
#   'Published_date': '2024-03-29T03:38:04Z',
#   'Duration': 'PT2M55S',
#   'Views': '10298261',
#   'Likes': '308328',
#   'Comments': '14530',
#   'Favorite_count': '0',
#   'Definition': 'hd',
#   'Caption_status': 'false'},
#  {'Channel_name': 'SHUBH',
#   'Channel_id': 'UCtGbExCzlwmsyWKpxLnyEww',
#   'Video_id': 'jjiC7PfoIaY',
#   'Title': 'Shubh - Hood Anthem (Official Music Video)',
#   'Tags': ['shubh',
#    'hoodanthem',
#    'newpunjabisongs',
#    'punjabisongs2024',
#    'latestpunjabisongs',
#    'leoep',
#    'shubhleo',
#    'hood',
#    'anthem',
#    'punjabivideo'],
#   'Thumbnail': 'https://i.ytimg.com/vi/jjiC7PfoIaY/default.jpg',
#   'Description': 'Singer/Lyrics/Composer - Shubh\nMusic production - xxDanyRose\nMix - mixedbyswitch , ProdGK , Gurjit Thind\nMaster - Joe LaPorta (Sterling Sound)\nDolby Atmos Mix/Master - Gurjit Thind\nVideo Director - Rubbal GTR\nProducer - Sushmita Kohli\nDOP - Rithvik Reddy\n1st AD - Siddhesh Pandeyy\nEditor - Aris Cline\nColorist - Vijey Adhitya\n\nINSTAGRAM - https://www.instagram.com/shubhworldwide/',
#   'Published_date': '2024-02-02T12:51:29Z',
#   'Duration': 'PT3M14S',
#   'Views': '7799163',
#   'Likes': '262061',
#   'Comments': '13137',
#   'Favorite_count': '0',
#   'Definition': 'hd',
#   'Caption_status': 'false'},
#  {'Channel_name': 'SHUBH',
#   'Channel_id': 'UCtGbExCzlwmsyWKpxLnyEww',
#   'Video_id': 'Y5HIqjf3rek',
#   'Title': 'Shubh - Safety Off (Official Music Video)',
#   'Tags': ['safetyoff',
#    'shubh',
#    '12bor',
#    'gunna4',
#    'punjabisongs2024',
#    'newpunjabisongs2024',
#    'newpunjabisongs',
#    'punjabisongs',
#    'newvideosongs',
#    'leo',
#    'shubhalbum',
#    'kingshit'],
#   'Thumbnail': 'https://i.ytimg.com/vi/Y5HIqjf3rek/default.jpg',
#   'Description': 'Singer/Lyrics/Composer - Shubh\nMusic production - waitaminute\nMix - ProdGK , Gurjit Thind\nMaster - Joe LaPorta (Sterling Sound)\nDolby Atmos Mix/Master - Gurjit Thind\nVideo Director: Rubbal GTR\n\nINSTAGRAM - https://www.instagram.com/shubhworldwide/\n\n                 ***** EXPLICIT CONTENT *****',
#   'Published_date': '2024-01-12T05:04:38Z',
#   'Duration': 'PT2M34S',
#   'Views': '15938484',
#   'Likes': '365634',
#   'Comments': '19862',
#   'Favorite_count': '0',
#   'Definition': 'hd',
#   'Caption_status': 'true'},
#  {'Channel_name': 'SHUBH',
#   'Channel_id': 'UCtGbExCzlwmsyWKpxLnyEww',
#   'Video_id': 'd2ofxg8pHfQ',
#   'Title': 'Shubh - King Shit (Official Audio)',
#   'Tags': ['kingshit',
#    'shubh',
#    'shubhnewep',
#    'newpunjabisongs2024',
#    'newsongs2024',
#    'punjabisongs',
#    'newpunjabisongs'],
#   'Thumbnail': 'https://i.ytimg.com/vi/d2ofxg8pHfQ/default.jpg',
#   'Description': 'Singer/Lyrics/Composer - Shubh\nMusic production - Tatay Produciendo\nMix - mixedbyswitch , Gurjit Thind\nMaster - Joe LaPorta (Sterling Sound)\nDolby Atmos Mix/Master - Gurjit Thind\n\nINSTAGRAM - https://www.instagram.com/shubhworldwide/',
#   'Published_date': '2024-01-05T08:38:29Z',
#   'Duration': 'PT3M48S',
#   'Views': '61689816',
#   'Likes': '1119372',
#   'Comments': '64359',
#   'Favorite_count': '0',
#   'Definition': 'hd',
#   'Caption_status': 'false'},
#  {'Channel_name': 'SHUBH',
#   'Channel_id': 'UCtGbExCzlwmsyWKpxLnyEww',
#   'Video_id': 'IAvw60x0Kn4',
#   'Title': 'Shubh - You and Me (Official Audio)',
#   'Tags': ['youandme',
#    'shubh',
#    'naintere',
#    'leo',
#    'romanticsong',
#    'punjabisong',
#    'newpunjabisongs',
#    'newsongs',
#    'punjabisongs2023',
#    'newsongs2023'],
#   'Thumbnail': 'https://i.ytimg.com/vi/IAvw60x0Kn4/default.jpg',
#   'Description': 'Singer/Lyrics/Composer - Shubh\nMusic production - Impala Beats\nMix - mixedbyswitch , Gurjit Thind\nMaster - Joe LaPorta (Sterling Sound)\nDolby Atmos Mix/Master - Gurjit Thind\n\nINSTAGRAM - https://www.instagram.com/shubhworldwide/',
#   'Published_date': '2024-01-05T08:37:56Z',
#   'Duration': 'PT2M51S',
#   'Views': '27351008',
#   'Likes': '451659',
#   'Comments': '11976',
#   'Favorite_count': '0',
#   'Definition': 'hd',
#   'Caption_status': 'false'},
#  {'Channel_name': 'SHUBH',
#   'Channel_id': 'UCtGbExCzlwmsyWKpxLnyEww',
#   'Video_id': 'EWlQVvCX8y0',
#   'Title': 'Shubh - Hood Anthem (Official Audio)',
#   'Tags': ['hoodanthem',
#    'shubh',
#    'newpunjabisongs2024',
#    'newsongs',
#    'leo',
#    'shubhep',
#    'newpunjabisongs',
#    'kaalekamm'],
#   'Thumbnail': 'https://i.ytimg.com/vi/EWlQVvCX8y0/default.jpg',
#   'Description': 'Singer/Lyrics/Composer - Shubh\nMusic production - xxDanyRose\nMix - mixedbyswitch , ProdGK , Gurjit Thind\nMaster - Joe LaPorta (Sterling Sound)\nDolby Atmos Mix/Master - Gurjit Thind\n\nINSTAGRAM - https://www.instagram.com/shubhworldwide/',
#   'Published_date': '2024-01-05T08:37:36Z',
#   'Duration': 'PT3M14S',
#   'Views': '4603798',
#   'Likes': '124990',
#   'Comments': '4863',
#   'Favorite_count': '0',
#   'Definition': 'hd',
#   'Caption_status': 'false'},
#  {'Channel_name': 'SHUBH',
#   'Channel_id': 'UCtGbExCzlwmsyWKpxLnyEww',
#   'Video_id': 'LjfY3qSTBQc',
#   'Title': 'Shubh - Safety Off (Official Audio)',
#   'Tags': ['shubh',
#    'safetyoff',
#    'newpunjabisongs',
#    'newpunjabisongs2024',
#    'newsongs2024',
#    'shubhep',
#    'nosafety',
#    'gunna4',
#    'bande2',
#    '12bore'],
#   'Thumbnail': 'https://i.ytimg.com/vi/LjfY3qSTBQc/default.jpg',
#   'Description': 'Singer/Lyrics/Composer - Shubh\nMusic production - waitaminute\nMix - ProdGK , Gurjit Thind\nMaster - Joe LaPorta (Sterling Sound)\nDolby Atmos Mix/Master - Gurjit Thind\n\nINSTAGRAM - https://www.instagram.com/shubhworldwide/',
#   'Published_date': '2024-01-05T08:37:08Z',
#   'Duration': 'PT2M24S',
#   'Views': '5398664',
#   'Likes': '165897',
#   'Comments': '10045',
#   'Favorite_count': '0',
#   'Definition': 'hd',
#   'Caption_status': 'false'},
#  {'Channel_name': 'SHUBH',
#   'Channel_id': 'UCtGbExCzlwmsyWKpxLnyEww',
#   'Video_id': '0pWsCiBvLOk',
#   'Title': 'Shubh - One Love (Official Audio)',
#   'Tags': ['Shubh', 'one love', 'Shubh one love', 'shubh latest song'],
#   'Thumbnail': 'https://i.ytimg.com/vi/0pWsCiBvLOk/default.jpg',
#   'Description': 'Singer/Lyrics/Composer - Shubh\nMusic Production: Kony Ala\nMix & Master: mixedbyswitch\nDolby Atmos Mix/Master: Gurjit Thind\n\nINSTAGRAM - https://www.instagram.com/shubhworldwide/',
#   'Published_date': '2023-08-18T10:32:15Z',
#   'Duration': 'PT2M40S',
#   'Views': '104422155',
#   'Likes': '1213487',
#   'Comments': '37532',
#   'Favorite_count': '0',
#   'Definition': 'hd',
#   'Caption_status': 'false'},
#  {'Channel_name': 'SHUBH',
#   'Channel_id': 'UCtGbExCzlwmsyWKpxLnyEww',
#   'Video_id': 'bJfI6x1obEg',
#   'Title': 'See you soon…',
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/bJfI6x1obEg/default.jpg',
#   'Description': '',
#   'Published_date': '2023-07-29T05:34:49Z',
#   'Duration': 'PT1M23S',
#   'Views': '2028079',
#   'Likes': '90935',
#   'Comments': '3351',
#   'Favorite_count': '0',
#   'Definition': 'hd',
#   'Caption_status': 'false'},
#  {'Channel_name': 'SHUBH',
#   'Channel_id': 'UCtGbExCzlwmsyWKpxLnyEww',
#   'Video_id': '4tywp83zkmk',
#   'Title': 'Shubh - Cheques (Official Music Video)',
#   'Tags': ['cheques',
#    'stillrollin',
#    'jekoishakni',
#    'cheque',
#    'new punjabi songs',
#    'cheque video',
#    'punjabi songs',
#    'new punjabi songs 2023',
#    'punjabi songs 2023',
#    'still rollin album',
#    'official video',
#    'cheques video',
#    'cheques official video'],
#   'Thumbnail': 'https://i.ytimg.com/vi/4tywp83zkmk/default.jpg',
#   'Description': 'Singer/Lyrics/Composer - Shubh\nMusic Production: Tatay Produciendo\nMix: Lavish Dhiman\nMaster: mixedbyswitch\nDolby Atmos Mix/Master: Gurjit Thind\nVideo Director: Rubbal GTR\n\nINSTAGRAM - https://www.instagram.com/shubhworldwide/',
#   'Published_date': '2023-07-21T11:33:49Z',
#   'Duration': 'PT3M9S',
#   'Views': '205640292',
#   'Likes': '2286567',
#   'Comments': '60633',
#   'Favorite_count': '0',
#   'Definition': 'hd',
#   'Caption_status': 'true'},
#  {'Channel_name': 'SHUBH',
#   'Channel_id': 'UCtGbExCzlwmsyWKpxLnyEww',
#   'Video_id': 'vyrPwLoIYkc',
#   'Title': 'Shubh - Dior (Official Music Video)',
#   'Tags': ['Shubh',
#    'dior video',
#    'Still rollin Album',
#    'Official music video',
#    'Shubh Dior song',
#    'Latest release',
#    'Punjabi',
#    'hathdior',
#    'new punjabi songs',
#    'punjabi songs',
#    'new songs 2023',
#    'gall ch gold',
#    'gaddi 2 door',
#    'punjabi songs 2023'],
#   'Thumbnail': 'https://i.ytimg.com/vi/vyrPwLoIYkc/default.jpg',
#   'Description': 'Singer/Lyrics/Composer - Shubh\nMusic Production: Lavish Dhiman\nMix: Lavish Dhiman\nMaster: mixedbyswitch\nVideo Director: Rubbal GTR\n\n\nINSTAGRAM - https://www.instagram.com/shubhworldwide/',
#   'Published_date': '2023-07-18T11:46:49Z',
#   'Duration': 'PT2M29S',
#   'Views': '25881034',
#   'Likes': '398096',
#   'Comments': '8320',
#   'Favorite_count': '0',
#   'Definition': 'hd',
#   'Caption_status': 'true'},
#  {'Channel_name': 'SHUBH',
#   'Channel_id': 'UCtGbExCzlwmsyWKpxLnyEww',
#   'Video_id': 'oUOdKwzuvX0',
#   'Title': 'Shubh - OG (Official Music Video)',
#   'Tags': ['OG Shubh',
#    'Full Video',
#    'Still Rollin Album',
#    'newsong2023',
#    'punjabisongs2023',
#    'og',
#    'shubh',
#    'stillrollin',
#    'tenujolagda'],
#   'Thumbnail': 'https://i.ytimg.com/vi/oUOdKwzuvX0/default.jpg',
#   'Description': 'Singer/Lyrics/Composer: Shubh\nMusic Production: Karan Kanchan\nMix: Hanish Taneja\nMaster: mixedbyswitch\nDolby Atmos Mix/Master: Gurjit Thind\nVideo Director: Rubbal GTR\n\nINSTAGRAM - https://www.instagram.com/shubhworldwide/',
#   'Published_date': '2023-05-26T06:00:16Z',
#   'Duration': 'PT3M21S',
#   'Views': '18025838',
#   'Likes': '274713',
#   'Comments': '8637',
#   'Favorite_count': '0',
#   'Definition': 'hd',
#   'Caption_status': 'true'},
#  {'Channel_name': 'SHUBH',
#   'Channel_id': 'UCtGbExCzlwmsyWKpxLnyEww',
#   'Video_id': '0mCVpUDCkEk',
#   'Title': 'Shubh - Still Rollin (Official Music Video)',
#   'Tags': ['Still Rollin Official Video',
#    'Shubh',
#    'Still Rollin Shubh',
#    'Full Video',
#    '22inch',
#    'gaddineevi',
#    'tireghumde',
#    'stillrolling',
#    'mangnakimang',
#    '410',
#    '2023',
#    'album'],
#   'Thumbnail': 'https://i.ytimg.com/vi/0mCVpUDCkEk/default.jpg',
#   'Description': 'Singer/Lyrics/Composer: Shubh\nMusic Production: Beast Inside Beats\nCo-Music Production: Lavish Dhiman\nMix: Lavish Dhiman\nMaster: mixedbyswitch\nDolby Atmos Mix/Master: Gurjit Thind\nVideo Director: Rubbal GTR\n\nINSTAGRAM - https://www.instagram.com/shubhworldwide/',
#   'Published_date': '2023-05-19T07:19:56Z',
#   'Duration': 'PT2M52S',
#   'Views': '78744097',
#   'Likes': '869579',
#   'Comments': '28436',
#   'Favorite_count': '0',
#   'Definition': 'hd',
#   'Caption_status': 'true'},
#  {'Channel_name': 'SHUBH',
#   'Channel_id': 'UCtGbExCzlwmsyWKpxLnyEww',
#   'Video_id': 'xOeniWOjA3M',
#   'Title': 'Shubh - Ice (Official Audio)',
#   'Tags': ['ice',
#    'shubh',
#    'stillrollin',
#    '2023',
#    'newsong',
#    'guttlagge',
#    'roll',
#    'stillrolling',
#    'price',
#    'album'],
#   'Thumbnail': 'https://i.ytimg.com/vi/xOeniWOjA3M/default.jpg',
#   'Description': 'Singer/Lyrics/Composer - Shubh\nMusic Production: Lavish Dhiman\nCo-Production: Stunnah \nMix: Lavish Dhiman\nMaster: mixedbyswitch\nDolby Atmos Mix/Master: Gurjit Thind\nVisuals: CG Dawn \n\nINSTAGRAM - https://www.instagram.com/shubhworldwide/',
#   'Published_date': '2023-05-19T07:16:19Z',
#   'Duration': 'PT2M55S',
#   'Views': '6362478',
#   'Likes': '99221',
#   'Comments': '2418',
#   'Favorite_count': '0',
#   'Definition': 'hd',
#   'Caption_status': 'false'},
#  {'Channel_name': 'SHUBH',
#   'Channel_id': 'UCtGbExCzlwmsyWKpxLnyEww',
#   'Video_id': 'DAqxAqq_jhg',
#   'Title': 'Shubh - Cheques (Official Audio)',
#   'Tags': ['cheques',
#    'checks',
#    'check',
#    'shubh',
#    'stillrollin',
#    'stillrolling',
#    'album',
#    '2023',
#    'karicheck',
#    'newsong'],
#   'Thumbnail': 'https://i.ytimg.com/vi/DAqxAqq_jhg/default.jpg',
#   'Description': 'Singer/Lyrics/Composer - Shubh\nMusic Production: Tatay Produciendo\nMix: Lavish Dhiman\nMaster: mixedbyswitch\nDolby Atmos Mix/Master: Gurjit Thind\nVisuals: CG Dawn \n\nINSTAGRAM - https://www.instagram.com/shubhworldwide/',
#   'Published_date': '2023-05-19T07:15:49Z',
#   'Duration': 'PT3M4S',
#   'Views': '43070004',
#   'Likes': '558296',
#   'Comments': '11784',
#   'Favorite_count': '0',
#   'Definition': 'hd',
#   'Caption_status': 'false'},
#  {'Channel_name': 'SHUBH',
#   'Channel_id': 'UCtGbExCzlwmsyWKpxLnyEww',
#   'Video_id': 'FxoBzZhEdjo',
#   'Title': 'Shubh - OG (Official Audio)',
#   'Tags': ['og',
#    'shubh',
#    'stillrollin',
#    'stillrolling',
#    'tenujolagda',
#    'ohnhi',
#    'newalbum',
#    '2023'],
#   'Thumbnail': 'https://i.ytimg.com/vi/FxoBzZhEdjo/default.jpg',
#   'Description': 'Singer/Lyrics/Composer - Shubh\nMusic Production: Karan Kanchan\nMix: Hanish Taneja\nMaster: mixedbyswitch\nDolby Atmos Mix/Master: Gurjit Thind\nVisuals: CG Dawn\n\n INSTAGRAM - https://www.instagram.com/shubhworldwide/',
#   'Published_date': '2023-05-19T07:15:23Z',
#   'Duration': 'PT3M18S',
#   'Views': '2845545',
#   'Likes': '53271',
#   'Comments': '1630',
#   'Favorite_count': '0',
#   'Definition': 'hd',
#   'Caption_status': 'false'},
#  {'Channel_name': 'SHUBH',
#   'Channel_id': 'UCtGbExCzlwmsyWKpxLnyEww',
#   'Video_id': 'KaZRiIsQjhM',
#   'Title': 'Shubh - Ruthless (Official Audio)',
#   'Tags': ['gallan',
#    'song',
#    'shubh',
#    'stillrollin',
#    'stillrolling',
#    'newalbum',
#    '2023',
#    'newsong',
#    'ruthless',
#    'kammbolde'],
#   'Thumbnail': 'https://i.ytimg.com/vi/KaZRiIsQjhM/default.jpg',
#   'Description': 'Singer/Lyrics/Composer - Shubh\nMusic Production: Karan Kanchan\nMix: Hanish Taneja\nMaster: mixedbyswitch\nDolby Atmos Mix/Master: Gurjit Thind\nVisuals: CG Dawn \n\nINSTAGRAM - https://www.instagram.com/shubhworldwide/',
#   'Published_date': '2023-05-19T07:14:38Z',
#   'Duration': 'PT3M25S',
#   'Views': '3256848',
#   'Likes': '66350',
#   'Comments': '3054',
#   'Favorite_count': '0',
#   'Definition': 'hd',
#   'Caption_status': 'false'},
#  {'Channel_name': 'SHUBH',
#   'Channel_id': 'UCtGbExCzlwmsyWKpxLnyEww',
#   'Video_id': 'SeC91H4nWCk',
#   'Title': 'Shubh - Dior (Official Audio)',
#   'Tags': ['dior',
#    'shubh',
#    'stillrollin',
#    'stillrolling',
#    '2023',
#    'album',
#    'newsong',
#    'gold',
#    'hathdior',
#    '2door'],
#   'Thumbnail': 'https://i.ytimg.com/vi/SeC91H4nWCk/default.jpg',
#   'Description': 'Singer/Lyrics/Composer - Shubh\nMusic Production: Lavish Dhiman\nMix: Lavish Dhiman\nMaster: mixedbyswitch\nVisuals: CG Dawn \n\nINSTAGRAM - https://www.instagram.com/shubhworldwide/',
#   'Published_date': '2023-05-19T07:14:09Z',
#   'Duration': 'PT2M20S',
#   'Views': '3571464',
#   'Likes': '66434',
#   'Comments': '2451',
#   'Favorite_count': '0',
#   'Definition': 'hd',
#   'Caption_status': 'false'},
#  {'Channel_name': 'SHUBH',
#   'Channel_id': 'UCtGbExCzlwmsyWKpxLnyEww',
#   'Video_id': 'FJm2CR1o_hI',
#   'Title': 'Shubh - The Flow (Official Audio)',
#   'Tags': ['flow',
#    'shubh',
#    'stillrolling',
#    'stillrollin',
#    'newsong',
#    '2023',
#    'album',
#    'newalbum'],
#   'Thumbnail': 'https://i.ytimg.com/vi/FJm2CR1o_hI/default.jpg',
#   'Description': 'Singer/Lyrics/Composer - Shubh\nMusic Production: Tatay Produciendo\nMix: Lavish Dhiman\nMaster: mixedbyswitch\nDolby Atmos Mix/Master: Gurjit Thind\nVisuals: CG Dawn \n\nINSTAGRAM - https://www.instagram.com/shubhworldwide/',
#   'Published_date': '2023-05-19T07:13:43Z',
#   'Duration': 'PT2M54S',
#   'Views': '1969684',
#   'Likes': '61375',
#   'Comments': '3078',
#   'Favorite_count': '0',
#   'Definition': 'hd',
#   'Caption_status': 'false'},
#  {'Channel_name': 'SHUBH',
#   'Channel_id': 'UCtGbExCzlwmsyWKpxLnyEww',
#   'Video_id': 'IrzowkE4h1w',
#   'Title': 'Shubh - Still Rollin (Official Album Trailer)',
#   'Tags': ['stillrollin',
#    'shubh',
#    'trailer',
#    'album',
#    'stillrolling',
#    'werollin',
#    'teaser',
#    '2023',
#    'newalbum',
#    'debutalbum',
#    'dab32bor',
#    'may19',
#    'may'],
#   'Thumbnail': 'https://i.ytimg.com/vi/IrzowkE4h1w/default.jpg',
#   'Description': 'OUT ON MAY 19',
#   'Published_date': '2023-05-12T09:50:42Z',
#   'Duration': 'PT1M2S',
#   'Views': '1100220',
#   'Likes': '68456',
#   'Comments': '8098',
#   'Favorite_count': '0',
#   'Definition': 'hd',
#   'Caption_status': 'false'},
#  {'Channel_name': 'SHUBH',
#   'Channel_id': 'UCtGbExCzlwmsyWKpxLnyEww',
#   'Video_id': 'eD3TP-C3nYE',
#   'Title': 'Her (Official Audio) - Shubh',
#   'Tags': ['punjabisongs2022',
#    'newpunjabisongs',
#    'shubh',
#    'noloveshubh',
#    'shubhnolove',
#    'latestpunjabisongs',
#    'newpunjabisongs2022',
#    '2022punjabisongs',
#    'drill',
#    'hiphop',
#    'Her',
#    'hershubh'],
#   'Thumbnail': 'https://i.ytimg.com/vi/eD3TP-C3nYE/default.jpg',
#   'Description': 'Singer/Lyrics/Composer - Shubh\nMusic/Mix&Master - Lavish Dhiman\nVisuals - SimarVFX\n\nINSTAGRAM - https://www.instagram.com/shubhworldwide/',
#   'Published_date': '2022-11-30T05:06:10Z',
#   'Duration': 'PT2M35S',
#   'Views': '23627880',
#   'Likes': '402100',
#   'Comments': '19494',
#   'Favorite_count': '0',
#   'Definition': 'hd',
#   'Caption_status': 'false'},
#  {'Channel_name': 'SHUBH',
#   'Channel_id': 'UCtGbExCzlwmsyWKpxLnyEww',
#   'Video_id': 'xR3V5Ow2dTI',
#   'Title': 'Shubh - Baller (Official Music Video)',
#   'Tags': ['baller',
#    'shubh',
#    'charche',
#    'trend',
#    'shubhworldwide',
#    'punjabisongs2022',
#    'newpunjabisongs',
#    'punjabi',
#    'latestpunjabisongs'],
#   'Thumbnail': 'https://i.ytimg.com/vi/xR3V5Ow2dTI/default.jpg',
#   'Description': 'Singer/Lyrics/Composer - Shubh\nMusic - Ikky\nMix & Master - mixedbyswitch\nProduction - Revive Films\nDirector - Amrit Thind\nEditor -  Apal Sidhu\nPhotos - Dusty Loops\n\nINSTAGRAM https://www.instagram.com/shubhworldwide/',
#   'Published_date': '2022-09-09T04:03:00Z',
#   'Duration': 'PT2M34S',
#   'Views': '95708097',
#   'Likes': '1251964',
#   'Comments': '27256',
#   'Favorite_count': '0',
#   'Definition': 'hd',
#   'Caption_status': 'false'},
#  {'Channel_name': 'SHUBH',
#   'Channel_id': 'UCtGbExCzlwmsyWKpxLnyEww',
#   'Video_id': 'I1nX5EuvwzE',
#   'Title': 'Shubh - Elevated (Official Music Video)',
#   'Tags': ['new punjabi songs',
#    'punjabi hip hop',
#    'punjabi',
#    'punjabi songs',
#    'latest punjabi songs',
#    'new punjabi song',
#    'hip hop',
#    'latest punjabi songs 2022',
#    'punjabi rap',
#    'new punjabi songs 2022',
#    'latest punjabi song',
#    'punjabi hip hop songs',
#    'punjabi song',
#    'desi hip hop songs',
#    'new punjabi song 2022',
#    'new punjabi songs 2021',
#    'hit punjabi songs',
#    'punjabi music',
#    'new punjabi rap',
#    'punjabi song new',
#    'punjabi rap songs',
#    'new punjabi songs this week',
#    'latest punjabi song 2022',
#    'Shubh',
#    'Shubh new songs',
#    'Elevated'],
#   'Thumbnail': 'https://i.ytimg.com/vi/I1nX5EuvwzE/default.jpg',
#   'Description': 'Singer/Lyrics/Composer - Shubh\nBeat - Tatay Produciendo\nMix & Master - thiarajxtt\nVideo - Rubbal GTR \nDOP - Cole Spritz \n\nINSTAGRAM -  https://instagram.com/shubhworldwide\n\nAudio Streaming - \nApple Music: https://apple.co/38vX9vN\nSpotify: https://spoti.fi/3LCPRo6\nGaana: http://bit.ly/Elevated-Gaana\nWynk: http://bit.ly/Elevated-Wynk\nAmazon Music: https://amzn.to/3r5sTOy\nYouTube Music: http://bit.ly/Elevated-YouTubeMusic\nResso: https://bit.ly/3x5tVhj',
#   'Published_date': '2022-04-06T15:00:11Z',
#   'Duration': 'PT3M50S',
#   'Views': '110528472',
#   'Likes': '1481864',
#   'Comments': '26446',
#   'Favorite_count': '0',
#   'Definition': 'hd',
#   'Caption_status': 'false'},
#  {'Channel_name': 'SHUBH',
#   'Channel_id': 'UCtGbExCzlwmsyWKpxLnyEww',
#   'Video_id': '6RrEQJNZwPQ',
#   'Title': 'No Love (Official Audio) - Shubh',
#   'Tags': ['punjabisongs2022',
#    'newpunjabisongs',
#    'shubh',
#    'noloveshubh',
#    'shubhnolove',
#    'latestpunjabisongs',
#    'newpunjabisongs2022',
#    '2022punjabisongs',
#    'drill',
#    'hiphop',
#    'eda ni chalde pyar',
#    'aida ni chalde pyar',
#    'chalde pyar',
#    'akhan vich',
#    'tutti ae adh vichkaar'],
#   'Thumbnail': 'https://i.ytimg.com/vi/6RrEQJNZwPQ/default.jpg',
#   'Description': 'Singer/Lyrics/Composer - Shubh\nMusic - Sosa\nMix & Master - thiarajxtt\n\nINSTAGRAM - https://www.instagram.com/shubhworldwide/',
#   'Published_date': '2022-02-25T13:24:23Z',
#   'Duration': 'PT2M51S',
#   'Views': '200762927',
#   'Likes': '2348989',
#   'Comments': '35699',
#   'Favorite_count': '0',
#   'Definition': 'hd',
#   'Caption_status': 'false'},
#  {'Channel_name': 'SHUBH',
#   'Channel_id': 'UCtGbExCzlwmsyWKpxLnyEww',
#   'Video_id': 'hV8EGTjzD2s',
#   'Title': 'We Rollin (Official Video) - Shubh | Rubbal GTR',
#   'Tags': ['punjabisongs2022',
#    'punjabi songs',
#    'latest punjabi songs',
#    'we rollin shubh',
#    'shubh',
#    'elevated shubh',
#    'offshore shubh',
#    'shubh punjabi songs',
#    'new punjabi songs'],
#   'Thumbnail': 'https://i.ytimg.com/vi/hV8EGTjzD2s/default.jpg',
#   'Description': 'Singer/Lyrics/Composer - Shubh\nMusic - Anabolic Beatz\nMix & Master - thiarajxtt\nVideo - Rubbal GTR\nDOP - Cole Spritz\n\nOut on All Platforms - https://bit.ly/WeRollin\n\nINSTAGRAM - https://www.instagram.com/shubhworldwide/',
#   'Published_date': '2022-02-12T06:33:24Z',
#   'Duration': 'PT3M35S',
#   'Views': '108304331',
#   'Likes': '1311004',
#   'Comments': '23811',
#   'Favorite_count': '0',
#   'Definition': 'hd',
#   'Caption_status': 'false'},
#  {'Channel_name': 'SHUBH',
#   'Channel_id': 'UCtGbExCzlwmsyWKpxLnyEww',
#   'Video_id': 'ixgaS-3FfK4',
#   'Title': 'Offshore (Official Audio) - Shubh',
#   'Tags': ['shubh',
#    'punjabisongs2021',
#    'punjabinewsongs',
#    'offshore',
#    'werollin',
#    'elevated',
#    'newpunjabisongs',
#    'newpunjabisongs2021',
#    'latestpunjabisongs',
#    'latestpunjabisongs2021',
#    'hiphop',
#    'trap'],
#   'Thumbnail': 'https://i.ytimg.com/vi/ixgaS-3FfK4/default.jpg',
#   'Description': 'Singer/Lyrics/Composer - Shubh\nProd/Mix & Master - thiarajxtt\n\nINSTAGRAM - https://www.instagram.com/shubhworldwide/',
#   'Published_date': '2021-11-22T03:51:25Z',
#   'Duration': 'PT2M52S',
#   'Views': '24813446',
#   'Likes': '372137',
#   'Comments': '5975',
#   'Favorite_count': '0',
#   'Definition': 'hd',
#   'Caption_status': 'false'},
#  {'Channel_name': 'SHUBH',
#   'Channel_id': 'UCtGbExCzlwmsyWKpxLnyEww',
#   'Video_id': '9CvwbW9UhJc',
#   'Title': 'Elevated (Official Audio) - Shubh',
#   'Tags': ['punjabisongs2021',
#    'punjabisongs',
#    'newpunjabisongs',
#    'shubh',
#    'werollin',
#    'punjabinewsongs',
#    'newsongspunjabi',
#    '2021punjabisongs'],
#   'Thumbnail': 'https://i.ytimg.com/vi/9CvwbW9UhJc/default.jpg',
#   'Description': 'Singer/Lyrics/Composer - Shubh\nBeat - Tatay produciendo\nMix & Master - thiarajxtt\n\nINSTAGRAM - https://www.instagram.com/shubhworldwide/',
#   'Published_date': '2021-10-22T03:10:25Z',
#   'Duration': 'PT3M21S',
#   'Views': '80799635',
#   'Likes': '957148',
#   'Comments': '10824',
#   'Favorite_count': '0',
#   'Definition': 'hd',
#   'Caption_status': 'false'},
#  {'Channel_name': 'SHUBH',
#   'Channel_id': 'UCtGbExCzlwmsyWKpxLnyEww',
#   'Video_id': 'RLhuPD2ASKE',
#   'Title': 'We Rollin (Official Audio) - Shubh',
#   'Tags': ['shubh',
#    'werollin',
#    'rollin',
#    'kaalicar',
#    'kalicar',
#    'newsong',
#    'punjabisong',
#    'newpunjabisongs',
#    'hiphop',
#    'rap',
#    'werolling',
#    'shub',
#    'dabb32bore',
#    'we',
#    'latest',
#    '2021songs',
#    'punjabisongs2021',
#    'newsongs',
#    'bandana',
#    'punjabihiphop',
#    'latestpunjabisongs2021',
#    'latestpunjabisongs',
#    'newpunjabisongs2021',
#    'boombap'],
#   'Thumbnail': 'https://i.ytimg.com/vi/RLhuPD2ASKE/default.jpg',
#   'Description': 'Singer/Lyrics/Composer - Shubh\nMusic - Anabolic Beatz\nMix & Master - thiarajxtt\n\nINSTAGRAM https://www.instagram.com/shubhworldwide/',
#   'Published_date': '2021-09-17T04:04:00Z',
#   'Duration': 'PT3M19S',
#   'Views': '231602953',
#   'Likes': '2708839',
#   'Comments': '46418',
#   'Favorite_count': '0',
#   'Definition': 'hd',
#   'Caption_status': 'false'}]
